# %% [markdown]
# ## 1. Which is an example of a classification task?
#
# - A. Based on a patient's blood pressure, determine how much blood pressure medication (a dosage measured in milligrams) the patient should be prescribed.
# - B. Based on a patient's age and blood pressure, determine how much blood pressure medication (measured in milligrams) the patient should be prescribed.
# - C. Based on the size of each tumor, determine if each tumor is malignant (cancerous) or not.
#
# ---
#
# <details>
# <summary>
#     <font size='3', color='darkgreen'><b>Correct</b></font>
# </summary>
#
# <div class="alert alert-success">
# <b>C</b>
# <p>This task predicts one of two classes, malignant or not malignant.</p>
# </div>

# %% [markdown]
# ## 2. Recall the sigmoid function is $g(z) = \frac{1}{1 + e^{-z}}$. if z is a large positive number, then:
# > - Recall: 召回率
# > - positive: 正数
#
# ![image.png](attachment:image.png)
# - A. g(z) is near negative one(-1)
# - B. g(z) is near one (1)
# - C. g(z) is near zero (0)
# - D. g(z) is near 0.5
#
# ---
#
# <details>
# <summary>
#     <font size='3', color='darkgreen'><b>Correct</b></font>
# </summary>
# <div class="alert alert-success">
# <b>B</b>
# </div>

# %% [markdown]
# ## 3. A cat photo classification model predicts 1 if it's a cat, and 0 if it's not a cat. For a particular photograph, the logistic regression model outputs $g(z)$ (a number between 0 and 1). Which of these would be a reasonable criteria to decide whether to predict if it’s a cat?
# ![image.png](attachment:image.png)
# > - predict: 预测
# > - particular: 特定的
# > - reasonable: 合理的
# > - criteria: 标准
# > - decide: 决定
# > - whether: 是否
#
# - A. Predict it is a cat if g(z) >= 0.5
# - B. Predict it is a cat if g(z) < 0.5
# - C. Predict it is a cat if g(z) = 0.5
# - D. Predict it is a cat if g(z) < 0.7
#
# ---
#
# <details>
# <summary>
#     <font size='3', color='darkgreen'><b>Correct</b></font>
# </summary>
# <div class="alert alert-success">
# <b>A</b>
# <p>Think of g(z) as the probability that the photo is of a cat. When this number is at or above the threshold of 0.5, predict that it is a cat.</p>
# </div>

# %% [markdown]
# ## 4. True/False? No matter what features you use (including if you use polynomial features), the decision boundary learned by logistic regression will be a linear decision boundary.
#
#
# > - No matter: 无论如何
# > - polynomial: 多项式
# > - decision: 决定
# > - boundary: 边界
#
#
# - A. False
# - B. True
#
# ---
#
# <details>
# <summary>
#     <font size='3', color='darkgreen'><b>Correct</b></font>
# </summary>
# <div class="alert alert-success">
# <b>A</b>
# <p>The decision boundary can also be non-linear, as described in the lectures.</p>
# <ul>
# <li>decision boundary: 决策边界</li>
# <li>described: 描述</li>
# <li>lectures: 讲座</li>
# </ul>
# </div>
# </details>
#
# <details>
# <summary>
#     <font size='3' color='darkred'><b>Incorrect</b></font>
# </summary>
# <div class=="alert alert-error">
# <b>B</b>
# <p>
# The decision boundary can also be non-linear, as described in the lectures. For example, the decision boundary could be a curve or even an oval, among other possible shapes.
# </p>
# <ul>
# <li>lectures: 讲座</li>
# <li>curve: 曲线</li>
# <li>oval: 椭圆</li>
# <li>possible: 可能的</li>
# </ul>
# </div>
# </details>
