# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return np.log(x)

print(f(2))
print(np.e)
x = np.linspace(0.1, 10, 400)
y = f(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Graph of f(x) = log(x)')
plt.grid(True)
plt.show()
# Out:
# 0.6931471805599453
# 2.718281828459045
