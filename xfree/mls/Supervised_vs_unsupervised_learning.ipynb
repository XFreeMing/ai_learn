# %% [markdown]
# # 定义

# %% [markdown]
# - **supervised problem** : A problem in which we are required to predict a value is known
# > 监督学习问题：一个问题，这个问题是我们需要预测一个值，这个值是已知的
# - **unsupervised problem** : Unsupervised datasets do not have a target associated with them and in general, are more challenging to deal with when compared to supervised problems.
# > 无监督学习问题：无监督数据集没有与之相关的目标，一般来说，与监督问题相比，无监督问题更具挑战性。
# - **Clustering** : Clustering is the task of grouping together a set of objects in a way that objects in the same cluster are more similar to each other than to objects in other clusters.
# > 聚类：聚类是将一组对象分组的任务，使得同一聚类中的对象彼此之间的相似性大于其他聚类中的对象。
# - **PCA**: Principal Component Analysis(PCA) is a dimensionality reduction technique that projects the data into a lower dimensional space.
# > 主成分分析(PCA)是一种降维技术，它将数据投影到较低维空间中。
# - **t-SNE**: t-distributed Stochastic Neighbor Embedding(t-SNE), is a non-linear dimensionality reduction technique that is particularly well-suited for embedding high-dimensional data into a space of two or three dimensions, which can then be visualized in a scatter plot.
# > t分布随机邻域嵌入(t-SNE)是一种非线性降维技术，特别适用于将高维数据嵌入到二维或三维空间中，然后在散点图中可视化。

# %% [markdown]
# # 命题

# %% [markdown]
# 1. A supervised problem is considerably easier to tackle than an unsupervised one.
# > 监督问题比无监督问题容易解决得多。
# 2. Most of the time, it's also possible to convert a supervised dataset to unsupervised to see how they look like when plotted.
# > 大多数时候，还可以将监督数据集转换为无监督数据集，以查看绘制时的外观。

# %% [markdown]
# # 问题

# %% [markdown]
# 1. It must be noted that sometimes we might use regression in a classification setting depending on the metric used for evaluation. But we will come to that later.
# > 必须注意，有时我们可能会根据用于评估的指标在分类设置中使用回归。 但是我们以后会谈到这一点。
#
# 2. Clustering is one of the approaches that you can use for problems like this, but it must be noted that there are several other approaches available that can be applied to unsupervised problems.
# > 聚类是您可以用于此类问题的方法之一，但必须注意，还有其他几种方法可用于无监督问题。
# 3. what is evaluation techniques?
# > 评估技术是什么？
# 4. One question that arises all the time is how to find the optimal number of clisters in k-means clustering.
# > 一直存在的一个问题是如何在k-means聚类中找到最佳的集群数。
# 5. You have to find the number by cross-validation. Cross-validation will be discussed later in this book.
# > 您必须通过交叉验证找到该数字。 交叉验证将在本书后面讨论。

# %% [markdown]
# # Supervised and Unsupervised Learning

# %% [markdown]
# ## Part1

# %% [markdown]
# ![image.png](attachment:image.png)
# - As we see in figure 1,every row of the data is associated with a target or label.
# > 如图1所示，数据的每一行都与一个目标或标签相关联。
# - The columns are different features and rows represent different data points which are usually called samples.
# > 列是不同的特征，行代表不同的数据点，通常称为样本。
# - The example shows ten samples with ten features and a target variable which can be either a number or a category.
# > 该示例显示了具有十个特征和一个目标变量的十个样本，该目标变量可以是数字或类别。
# - If the target is categorical, the problem becomes a classification problem.
# > 如果目标是分类的，则问题变成了分类问题。
# - And if the target is a real number, the problem is defined as a regression problem.
# > 如果目标是实数，则问题被定义为回归问题。
# - Thus,supervised problems can be divided into two sub-classes:
#     - classification: predicting a category, e.g. dog or cat
#     - Regression: predicting a value, e.g. house proces.
# > 因此，监督问题可以分为两个子类：
#     - 分类：预测类别，例如狗或猫
#     - 回归：预测值，例如房屋价格。
# - Another type of machine learning peoblem is the unsupervised type.
# > 另一种类型的机器学习问题是无监督类型。
# - Unsupervised datasets do not have a target associated with them and in general,are more challenging to deal with when compared to supervised problems.
# > 无监督数据集没有与之相关的目标，一般来说，与监督问题相比，无监督问题更具挑战性。
# - Let's say you work in a financial firm which deals with credit card transactions. There is a lot of data that comes in every second.
# > 假设您在一家处理信用卡交易的金融公司工作。 每秒都会有大量数据进入。
# - The only problem is that it is difficult to find humans who will mark each and every transaction either as a vaild or genuine transaction or a fraud.
# > 唯一的问题是很难找到人类，他们会将每笔交易标记为有效或真实交易或欺诈。
# - When we do not have any information about a transaction being fraud or genuine, the problem becomes an unsupervised problem.
# > 当我们没有任何关于交易是欺诈还是真实的信息时，问题就变成了无监督的问题。
# - To tackle these kinds of problems we have to think about how many clusters can data be divided into.
# > 要解决这些问题，我们必须考虑数据可以分成多少个集群。
# - For a fraud detection problem,we can say that data can be divided into two classes(fraud or genuine).
# > 对于欺诈检测问题，我们可以说数据可以分为两类（欺诈或真实）。

# %% [markdown]
# ## Part2

# %% [markdown]
# ![image.png](attachment:image.png)
# - When we know the number of clusters, we can use a clustering algorithm for unsupervised problems.
# > 当我们知道集群的数量时，我们可以使用聚类算法来解决无监督的问题。
# - In figure 2, the data is assumed to have two classes, dark color represents fraud, and light color represents genuine transcations.
# > 在图2中，假设数据有两个类，深色表示欺诈，浅色表示真实的转换。
# - These classes, however, are not known to us before the clustering approach.
# > 但是，在聚类方法之前，我们不知道这些类。
# - After a clustering a algorithm is applied, we should be able to distinguish between the two assumed targets.
# > 应用聚类算法后，我们应该能够区分两个假定的目标。
# - To make sense of unsupervised problems, we can also use numerous decomposition technigues such as Principal Component Analysis(PCA), t-distributed Stochastic Neighbor Embedding(t-SNE), etc.
# > 为了理解无监督的问题，我们还可以使用许多分解技术，例如主成分分析（PCA），t分布随机邻域嵌入（t-SNE）等。
# - Supervised problems are easier to tackle in the sense that they can be evaluated easily.
# > 从某种意义上说，监督问题更容易解决，因为它们可以轻松评估。
# - Howerver, it is challenging to assess the results of unsupervised algorithms and a lot of human interference or heuristics are required.
# > 但是，评估无监督算法的结果具有挑战性，并且需要大量人为干预或启发式方法。
# - In this book, we will majorly be focusing on supervised data and models, but it does not mean that we will be ignoring the unsupervised data problems.
# > 在本书中，我们主要将关注监督数据和模型，但这并不意味着我们将忽略无监督数据问题。
# - Most of the time, when people start with data science or machine learning, they begin with very well-known datasets, for example, Titanic dataset, or Iris dataset which are supervised problems.
# > 大多数时候，当人们开始进行数据科学或机器学习时，他们会从非常著名的数据集开始，例如Titanic数据集或Iris数据集，这些都是监督问题。
# - In the Tianic dataset, you have to predict the survival of people aboard Titanic based on factors like their ticket class, gender, age, etc.
# > 在Tianic数据集中，您必须根据票务类别，性别，年龄等因素预测泰坦尼克号上人员的生存情况。
# - Similarly, in the iris dataset, you have to predict species of flower based on factors like sepal width, petal length, sepal length and petal width.
# > 同样，在鸢尾花数据集中，您必须根据萼片宽度，花瓣长度，萼片长度和花瓣宽度等因素预测花的物种。
# - Unsupervised datasets may include datasets for customer segmentation.
# > 无监督数据集可能包括用于客户细分的数据集。
# - For example, you have data for the customers visiting your e-commerce website or the data for customers visiting a store or a mall, and you would like to segment them or cluster them in different categorise.
# > 例如，您拥有访问电子商务网站的客户数据，或者访问商店或商场的客户数据，并且希望将它们分段或将它们分成不同的类别。
# - Another example of unsupervised datasets may include things like credit card fraud detection or just clustering several images.
# > 无监督数据集的另一个示例可能包括信用卡欺诈检测或仅聚类多个图像。

# %% [markdown]
# # Part3

# %% [markdown]
# ![image.png](attachment:image.png)
# - Figure 3 shows MNIST dataset which is a very popualr dataset of handwritten digits, and it is a supervised problem in which you are given the images of the numbers and the correct label associated with them.
# > 图3显示了MNIST数据集，这是一个非常受欢迎的手写数字数据集，它是一个监督问题，您将获得数字的图像以及与之相关的正确标签。
# - You have to build a model that can identify which digit is it when provided only with the image.
# > 您必须构建一个模型，该模型可以在仅提供图像时识别出它是哪个数字。
# - The dataset can easily be converted to an unsupervised setting for basic visualization.
# > 该数据集可以轻松转换为无监督设置以进行基本可视化。
# - If we do a t-Distributed Stochastic Neighbour Embedding(t-SNE) decomposition of this dataset, we can see that we can separate the images to some extent just by doing with two components on the image pixels.
# > 如果我们对此数据集进行t分布随机邻域嵌入（t-SNE）分解，我们可以看到仅通过对图像像素进行两个组件的操作，我们就可以在某种程度上将图像分开。

# %% [markdown]
# # Part4

# %% [markdown]
# - We use matplotlib and seaborn for plotting, numpy to handle the numerical arrays, pandas to create dataframes from the numerical arrays and scikit-learn (sklearn) to get the data and perform t-SNE.
# > 我们使用matplotlib和seaborn进行绘图，numpy处理数字数组，pandas从数字数组创建数据框架，scikit-learn（sklearn）获取数据并执行t-SNE。
# - After the imports, we need to either download the data and read it separately or use sklearn's built-in function that provides us with the MNIST dataset.
# > 导入后，我们需要下载数据并单独读取它，或者使用sklearn的内置函数，该函数为我们提供了MNIST数据集。
# - In this part of the code, we have fetched the data using sklearn datasets, and we have an array of pixel values and another array of targets.
# > 在代码的这一部分中，我们使用sklearn数据集获取了数据，并且我们有一个像素值数组和另一个目标数组。
# - pixel_valuse is a 2-dimensional array of shape 70000*784.
# > pixel_valuse是一个形状为70000 * 784的二维数组。
# - There are 70000 different images, each of size 28*28 pixels.
# > 有70000个不同的图像，每个图像大小为28 * 28像素。
# - Flattening 28*28 gives 784 data points.
# > 将28 * 28展平为784个数据点。
# - We can visualize the samples in this dataset by reshaping them to their oringinal shape and then plotting them using matplotlib.
# > 我们可以通过将样本重塑为其原始形状，然后使用matplotlib绘制它们来可视化此数据集。

# %% [markdown]
# # 代码

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn import manifold

# %matplotlib inline
data = datasets.fetch_openml(
    'mnist_784',
    version=1,
    return_X_y=True
)

pixel_values, targets = data
single_image = pixel_values.iloc[1, :].values.reshape(28, 28)
plt.imshow(single_image, cmap='gray')

# %% [markdown]
# - The most important step comes after we have grabbed the data.
# > 在获取数据之后，最重要的一步就是来了。
# - This step creates the t-SNE transformation of the data. We use only two components as we can visualize them well in a two-dimensional setting.
# > 此步骤创建数据的t-SNE转换。 我们仅使用两个组件，因为我们可以在二维设置中很好地可视化它们。
# - The transformed_data, in this case, is an array of shape 3000*2(3000 rows and 2 columns).
# > 在这种情况下，transformed_data是一个形状为3000 * 2（3000行和2列）的数组。
# - A data like this can be converted to a pandas dataframe by calling pd.DataFrame on the array.
# > 可以通过在数组上调用pd.DataFrame将此类数据转换为pandas数据框。
# - Here we are creating a pandas dataframe from a numpy array.
# > 在这里，我们正在从numpy数组创建pandas数据框。
# - There are three columns:x,y and targets. x and y are the two components from t-SNE decomposition and targets is the actual number.
# > 有三个列：x，y和目标。 x和y是t-SNE分解的两个组件，而目标是实际数字。
# - And fianlly, we can plot it using seaborn and matplotlib.
# > 最后，我们可以使用seaborn和matplotlib绘制它。

# %%
from sklearn.decomposition import PCA

# # Step 1: Use PCA to reduce dimensions
# pca = PCA(n_components=2)
# pca_transformed = pca.fit_transform(pixel_values.iloc[:3000, :])

# # Step 2: Scale the standard deviation of the first principal component to 1e-4
# pca_transformed[:, 0] = pca_transformed[:, 0] / np.std(pca_transformed[:, 0]) * 1e-4

# # Step 3: Run TSNE with the initialized data
# tsne = manifold.TSNE(n_components=2, init=pca_transformed, learning_rate='auto', random_state=42)
tsen = manifold.TSNE(n_components=2, init='pca', learning_rate='auto', random_state=42)
transformed_data = tsne.fit_transform(pixel_values.iloc[:3000, :])

tsne_df = pd.DataFrame(
    np.column_stack((transformed_data, targets[:3000])),
    columns=["x", "y", "targets"]
)
tsne_df.loc[:, "targets"] = tsne_df.targets.astype(int)
grid = sns.FacetGrid(tsne_df, hue="targets", height=8)
grid.map(plt.scatter, "x", "y").add_legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 13
#       3 # # Step 1: Use PCA to reduce dimensions
#       4 # pca = PCA(n_components=2)
#       5 # pca_transformed = pca.fit_transform(pixel_values.iloc[:3000, :])
#    (...)
#      10 # # Step 3: Run TSNE with the initialized data
#      11 # tsne = manifold.TSNE(n_components=2, init=pca_transformed, learning_rate='auto', random_state=42)
#      12 tsen = manifold.TSNE(n_components=2, init='pca', learning_rate='auto', random_state=42)
# ---> 13 transformed_data = tsne.fit_transform(pixel_values.iloc[:3000, :])
#      15 tsne_df = pd.DataFrame(
#      16     np.column_stack((transformed_data, targets[:3000])),
#      17     columns=["x", "y", "targets"]
#      18 )
#      19 tsne_df.loc[:, "targets"] = tsne_df.targets.astype(int)
#
# NameError: name 'tsne' is not defined

# %% [markdown]
# - This is one way of visualizing unsupervised datasets.
# > 这是可视化无监督数据集的一种方法。
# - We can also do k-means clustering on the same dataset and see how it performs in an unsupervised setting.
# > 我们还可以在同一数据集上执行k-means聚类，并查看它在无监督设置中的表现。
# - One question that arises all the time is how to find the optimal number of clisters in k-means clustering.
# > 一直存在的一个问题是如何在k-means聚类中找到最佳的集群数。
# - Well, there is no right answer.
# > 好吧，没有正确的答案。
# - MNIST is a supervised classification problem, and we converted it to an unsupervised problem only to check if it gives any kind of good results and it is apparent that we do get good results with decomposition with t-SNE.
# > MNIST是一个监督分类问题，我们将其转换为无监督问题，只是为了检查它是否提供任何良好的结果，并且显然我们确实可以通过t-SNE分解获得良好的结果。
# - The results would be even better if we use classification algorithms.
# > 如果使用分类算法，结果将更好。
# - What are they and how to use them? Let's look at them in the next chapters.
# > 它们是什么以及如何使用它们？ 让我们在下一章中看看它们。
